# %% [markdown]
# # Movie Night 🎬 - Movie Recommendation System
#
# A Streamlit application that recommends movies based on user selection using cosine similarity on various features.
#
# ## Features
#
# - **Interactive Sidebar:** Select your favorite movie.
# - **Detailed Movie Display:** Shows poster, genres, rating, release year, director, cast, and synopsis.
# - **Recommendations:** Provides similar movie suggestions with collapsible details.
# - **Custom Styling:** Enhanced UI with CSS for a modern look.
#
# ## How to Run
#
# 1. **Download the Python Script:**
#     -download provided file named `app.py`.
#
# 2. **Install Required Libraries:**
#    ```bash
#    pip install streamlit pandas numpy scikit-learn sentence-transformers

# %% [markdown]
# # Run the Streamlit App:
# ```bash
#   streamlit run recommendation_system_MAT124.py
