# %% [markdown]
# # Milestone 1: Data Collection
#
# ## Requirements
#
# - **Data Source**: movie data was scraped by using TMDb API
# - **Dataset Attributes**:
#   - Movie title
#   - Genre(s)
#   - Release year
#   - IMDb rating
#   - Number of user votes
#   - Movie description
#   - Poster URL

# %%
import csv
import logging
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import Dict, List, Optional
import requests
#Constants

API_KEY = "tmdb-api-key"  # Replace with a valid TMDb API key
BASE_URL = "https://api.themoviedb.org/3"
OUTPUT_FILENAME = "top20k_movies_project2.csv"
MAX_TOTAL_MOVIES = 20000

# Year-based configuration
START_YEAR = 1935
END_YEAR = 2024

# Adjust these values for different retrieval strategies
DEFAULT_MAX_PAGES_PER_YEAR = 100
DEFAULT_MIN_VOTE_COUNT = 100
RECENT_YEARS = [2024, 2023, 2022, 2021, 2020]
RECENT_MAX_PAGES_PER_YEAR = 500
RECENT_MIN_VOTE_COUNT = 80
MAX_WORKERS_YEAR = 5    # Threads used to process multiple years concurrently
MAX_WORKERS_PAGE = 10   # Threads used to fetch pages within a year concurrently
MAX_WORKERS_CREDITS = 10  # Threads used to fetch credits concurrently

# Retry logic configuration
RETRY_LIMIT = 3
RETRY_BACKOFF = 2  # seconds

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler("movie_fetcher.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

def fetch_json(url: str, params: Dict) -> Optional[Dict]:
    for attempt in range(1, RETRY_LIMIT + 1):
        try:
            response = requests.get(url, params=params, timeout=10)
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            logger.warning(
                f"Attempt {attempt} failed for URL: {url} with params: {params}. Error: {e}"
            )
            if attempt < RETRY_LIMIT:
                sleep_time = RETRY_BACKOFF ** attempt
                logger.info(f"Retrying after {sleep_time} seconds...")
                time.sleep(sleep_time)
            else:
                logger.error(
                    f"All {RETRY_LIMIT} attempts failed for URL: {url} with params: {params}."
                )
    return None


def fetch_genres() -> Dict[int, str]:
    url = f"{BASE_URL}/genre/movie/list"
    params = {"api_key": API_KEY, "language": "en-US"}
    data = fetch_json(url, params)
    if data and "genres" in data:
        genre_mapping = {genre["id"]: genre["name"] for genre in data["genres"]}
        logger.info(f"Fetched {len(genre_mapping)} genres.")
        return genre_mapping

    logger.error("Failed to fetch genres.")
    return {}


def fetch_movies_by_page(endpoint: str, page: int, filters: Optional[Dict] = None) -> Optional[Dict]:
    url = f"{BASE_URL}/{endpoint}"
    params = {
        "api_key": API_KEY,
        "language": "en-US",
        "page": page,
    }
    if filters:
        params.update(filters)
    return fetch_json(url, params)


def fetch_movie_credits(movie_id: int) -> Optional[Dict]:
    url = f"{BASE_URL}/movie/{movie_id}/credits"
    params = {"api_key": API_KEY, "language": "en-US"}
    return fetch_json(url, params)


def process_movie(movie: Dict, genres: Dict[int, str], unique_titles: set, min_vote_count: int) -> Optional[Dict]:
    title = movie.get("title")
    vote_count = movie.get("vote_count", 0)

    # Filter based on title uniqueness and minimum vote count
    if not title or title in unique_titles or vote_count < min_vote_count:
        return None

    unique_titles.add(title)

    movie_genres = [genres.get(g_id, "Unknown") for g_id in movie.get("genre_ids", [])]
    release_date = movie.get("release_date", "N/A")
    release_year = release_date.split("-")[0] if release_date != "N/A" else "N/A"
    poster_path = movie.get("poster_path")
    poster_url = f"https://image.tmdb.org/t/p/w500{poster_path}" if poster_path else "N/A"

    return {
        "id": movie.get("id"),
        "Title": title,
        "Genres": ", ".join(movie_genres),
        "Release Year": release_year,
        "IMDb Rating": movie.get("vote_average"),
        "Number of Votes": vote_count,
        "Description": movie.get("overview", "N/A"),
        "Poster URL": poster_url,
    }


def fetch_movies_for_year(year: int, genres: Dict[int, str], max_movies: int) -> List[Dict]:
    movies = []
    unique_titles = set()

    # Determine parameters based on whether the year is in the recent set
    if year in RECENT_YEARS:
        max_pages = RECENT_MAX_PAGES_PER_YEAR
        min_votes = RECENT_MIN_VOTE_COUNT
    else:
        max_pages = DEFAULT_MAX_PAGES_PER_YEAR
        min_votes = DEFAULT_MIN_VOTE_COUNT

    filters = {
        "primary_release_year": year,
        "sort_by": "vote_average.desc",
    }

    #fetch multiple pages of movie data
    with ThreadPoolExecutor(max_workers=MAX_WORKERS_PAGE) as executor:
        future_to_page = {
            executor.submit(fetch_movies_by_page, "discover/movie", page, filters): page
            for page in range(1, max_pages + 1)
        }

        for future in as_completed(future_to_page):
            page = future_to_page[future]
            data = future.result()
            if not data or "results" not in data:
                logger.warning(f"No data returned for year {year}, page {page}")
                continue

            for movie_data in data["results"]:
                processed = process_movie(movie_data, genres, unique_titles, min_votes)
                if processed:
                    movies.append(processed)
                    if len(movies) >= max_movies:
                        logger.debug(f"Reached max_movies limit: {max_movies} for year {year}")
                        return movies

    logger.info(f"Fetched {len(movies)} movies for year {year}.")
    return movies


def fetch_top_movies(genres: Dict[int, str], max_total_movies: int) -> List[Dict]:
    movies = []
    years = range(END_YEAR, START_YEAR - 1, -1)  # Start from the most recent year

    with ThreadPoolExecutor(max_workers=MAX_WORKERS_YEAR) as executor:
        future_to_year = {
            executor.submit(fetch_movies_for_year, year, genres, max_total_movies): year
            for year in years
        }

        for future in as_completed(future_to_year):
            year = future_to_year[future]
            try:
                year_movies = future.result()
                movies.extend(year_movies)
                logger.info(f"Total movies collected so far: {len(movies)}")

                if len(movies) >= max_total_movies:
                    logger.info(f"Reached the maximum limit of {max_total_movies} movies.")
                    break
            except Exception as e:
                logger.error(f"Error fetching movies for year {year}: {e}")

    logger.info(f"Total movies fetched: {len(movies)}")
    return movies[:max_total_movies]


def fetch_and_add_credits(movies: List[Dict], max_workers: int = MAX_WORKERS_CREDITS) -> None:
    logger.info("Starting to fetch credits for each movie...")
    start_time = time.time()
    total_movies = len(movies)
    completed = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_movie = {executor.submit(fetch_movie_credits, m["id"]): m for m in movies}

        for future in as_completed(future_to_movie):
            movie = future_to_movie[future]
            try:
                credits = future.result()
                if credits:
                    directors = [member["name"] for member in credits.get("crew", []) if member.get("job") == "Director"]
                    actors = [member["name"] for member in credits.get("cast", [])[:3]]
                else:
                    directors = []
                    actors = []

                movie["Director"] = ", ".join(directors) if directors else "N/A"
                movie["Cast"] = ", ".join(actors) if actors else "N/A"
            except Exception as e:
                logger.error(f"Error fetching credits for movie ID {movie['id']}: {e}")
                movie["Director"] = "N/A"
                movie["Cast"] = "N/A"
            finally:
                completed += 1
                # Log progress every 100 movies or at the end
                if completed % 100 == 0 or completed == total_movies:
                    logger.info(f"Fetched credits for {completed}/{total_movies} movies.")

    elapsed_time = time.time() - start_time
    logger.info(f"Completed fetching credits for all movies in {elapsed_time:.2f} seconds.")


def save_to_csv(movies: List[Dict], filename: str = OUTPUT_FILENAME) -> None:
    if not movies:
        logger.warning("No movies to save.")
        return

    fieldnames = [
        "Title",
        "Genres",
        "Release Year",
        "IMDb Rating",
        "Number of Votes",
        "Description",
        "Poster URL",
        "Director",
        "Cast"
    ]

    try:
        with open(filename, "w", newline="", encoding="utf-8") as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            for movie in movies:
                # Exclude 'id' and ensure all fields are present
                row = {field: movie.get(field, "N/A") for field in fieldnames}
                writer.writerow(row)
        logger.info(f"Saved {len(movies)} movies to '{filename}'.")
    except IOError as e:
        logger.error(f"Failed to write to CSV file {filename}: {e}")


def main():
    """
    Main execution function:
      1. Fetch genre mappings.
      2. Fetch top movies across the defined years.
      3. Fetch credits (Director and Cast) for each movie.
      4. Save the final dataset into a CSV file.
    """
    logger.info("Starting movie data fetching process...")
    start_time = time.time()

    genres = fetch_genres()
    if not genres:
        logger.error("Cannot proceed without genre data.")
        return

    # Fetch top movies 
    movies = fetch_top_movies(genres, MAX_TOTAL_MOVIES)
    # Fetch credits for Director and Cast info
    fetch_and_add_credits(movies)
    # Save results to CSV
    save_to_csv(movies)

    elapsed_time = time.time() - start_time
    logger.info(f"Execution time: {elapsed_time:.2f} seconds.")


if __name__ == "__main__":
    main()
# Out:
# 2024-12-09 18:28:33,201 [INFO] Starting movie data fetching process...
# 2024-12-09 18:28:33,525 [INFO] Fetched 19 genres.
# 2024-12-09 18:28:51,480 [INFO] Fetched 743 movies for year 2022.
# 2024-12-09 18:28:51,501 [INFO] Total movies collected so far: 743
# 2024-12-09 18:28:51,639 [INFO] Fetched 335 movies for year 2024.
# 2024-12-09 18:28:51,651 [INFO] Total movies collected so far: 1078
# 2024-12-09 18:28:51,791 [INFO] Fetched 623 movies for year 2023.
# 2024-12-09 18:28:51,804 [INFO] Total movies collected so far: 1701
# 2024-12-09 18:28:51,825 [INFO] Fetched 733 movies for year 2020.
# 2024-12-09 18:28:51,834 [INFO] Total movies collected so far: 2434
# 2024-12-09 18:28:51,911 [INFO] Fetched 774 movies for year 2021.
# 2024-12-09 18:28:51,917 [INFO] Total movies collected so far: 3208
# 2024-12-09 18:28:55,326 [INFO] Fetched 37 movies for year 2019.
# 2024-12-09 18:28:55,328 [INFO] Total movies collected so far: 3245
# 2024-12-09 18:28:55,585 [INFO] Fetched 22 movies for year 2018.
# 2024-12-09 18:28:55,590 [INFO] Total movies collected so far: 3267
# 2024-12-09 18:28:55,688 [INFO] Fetched 42 movies for year 2016.
# 2024-12-09 18:28:55,692 [INFO] Total movies collected so far: 3309
# 2024-12-09 18:28:55,812 [INFO] Fetched 14 movies for year 2017.
# 2024-12-09 18:28:55,814 [INFO] Total movies collected so far: 3323
# 2024-12-09 18:28:55,857 [INFO] Fetched 53 movies for year 2015.
# 2024-12-09 18:28:55,861 [INFO] Total movies collected so far: 3376
# 2024-12-09 18:28:59,379 [INFO] Fetched 118 movies for year 2014.
# 2024-12-09 18:28:59,387 [INFO] Total movies collected so far: 3494
# 2024-12-09 18:28:59,521 [INFO] Fetched 137 movies for year 2013.
# 2024-12-09 18:28:59,526 [INFO] Total movies collected so far: 3631
# 2024-12-09 18:28:59,663 [INFO] Fetched 134 movies for year 2012.
# 2024-12-09 18:28:59,671 [INFO] Total movies collected so far: 3765
# 2024-12-09 18:28:59,793 [INFO] Fetched 135 movies for year 2011.
# 2024-12-09 18:28:59,797 [INFO] Total movies collected so far: 3900
# 2024-12-09 18:28:59,921 [INFO] Fetched 157 movies for year 2010.
# 2024-12-09 18:28:59,923 [INFO] Total movies collected so far: 4057
# 2024-12-09 18:29:03,563 [INFO] Fetched 169 movies for year 2009.
# 2024-12-09 18:29:03,565 [INFO] Total movies collected so far: 4226
# 2024-12-09 18:29:03,742 [INFO] Fetched 203 movies for year 2008.
# 2024-12-09 18:29:03,745 [INFO] Total movies collected so far: 4429
# 2024-12-09 18:29:04,060 [INFO] Fetched 222 movies for year 2007.
# 2024-12-09 18:29:04,061 [INFO] Fetched 217 movies for year 2005.
# 2024-12-09 18:29:04,066 [INFO] Total movies collected so far: 4651
# 2024-12-09 18:29:04,071 [INFO] Total movies collected so far: 4868
# 2024-12-09 18:29:04,226 [INFO] Fetched 219 movies for year 2006.
# 2024-12-09 18:29:04,233 [INFO] Total movies collected so far: 5087
# 2024-12-09 18:29:07,923 [INFO] Fetched 220 movies for year 2004.
# 2024-12-09 18:29:07,931 [INFO] Total movies collected so far: 5307
# 2024-12-09 18:29:08,117 [INFO] Fetched 246 movies for year 2003.
# 2024-12-09 18:29:08,122 [INFO] Total movies collected so far: 5553
# 2024-12-09 18:29:08,209 [INFO] Fetched 232 movies for year 2001.
# 2024-12-09 18:29:08,213 [INFO] Total movies collected so far: 5785
# 2024-12-09 18:29:08,230 [INFO] Fetched 228 movies for year 2002.
# 2024-12-09 18:29:08,232 [INFO] Total movies collected so far: 6013
# 2024-12-09 18:29:08,647 [INFO] Fetched 227 movies for year 2000.
# 2024-12-09 18:29:08,648 [INFO] Total movies collected so far: 6240
# 2024-12-09 18:29:11,779 [INFO] Fetched 233 movies for year 1999.
# 2024-12-09 18:29:11,783 [INFO] Total movies collected so far: 6473
# 2024-12-09 18:29:12,090 [INFO] Fetched 237 movies for year 1998.
# 2024-12-09 18:29:12,098 [INFO] Total movies collected so far: 6710
# 2024-12-09 18:29:12,115 [INFO] Fetched 215 movies for year 1996.
# 2024-12-09 18:29:12,117 [INFO] Total movies collected so far: 6925
# 2024-12-09 18:29:12,129 [INFO] Fetched 210 movies for year 1997.
# 2024-12-09 18:29:12,131 [INFO] Total movies collected so far: 7135
# 2024-12-09 18:29:12,456 [INFO] Fetched 208 movies for year 1995.
# 2024-12-09 18:29:12,458 [INFO] Total movies collected so far: 7343
# 2024-12-09 18:29:15,368 [INFO] Fetched 206 movies for year 1994.
# 2024-12-09 18:29:15,371 [INFO] Total movies collected so far: 7549
# 2024-12-09 18:29:15,661 [INFO] Fetched 191 movies for year 1993.
# 2024-12-09 18:29:15,670 [INFO] Total movies collected so far: 7740
# 2024-12-09 18:29:15,714 [INFO] Fetched 177 movies for year 1992.
# 2024-12-09 18:29:15,717 [INFO] Total movies collected so far: 7917
# 2024-12-09 18:29:15,750 [INFO] Fetched 173 movies for year 1991.
# 2024-12-09 18:29:15,752 [INFO] Total movies collected so far: 8090
# 2024-12-09 18:29:16,086 [INFO] Fetched 175 movies for year 1990.
# 2024-12-09 18:29:16,088 [INFO] Total movies collected so far: 8265
# 2024-12-09 18:29:19,568 [INFO] Fetched 173 movies for year 1989.
# 2024-12-09 18:29:19,572 [INFO] Total movies collected so far: 8438
# 2024-12-09 18:29:19,898 [INFO] Fetched 161 movies for year 1987.
# 2024-12-09 18:29:19,901 [INFO] Total movies collected so far: 8599
# 2024-12-09 18:29:20,084 [INFO] Fetched 170 movies for year 1988.
# 2024-12-09 18:29:20,089 [INFO] Total movies collected so far: 8769
# 2024-12-09 18:29:20,182 [INFO] Fetched 164 movies for year 1986.
# 2024-12-09 18:29:20,188 [INFO] Total movies collected so far: 8933
# 2024-12-09 18:29:20,633 [INFO] Fetched 158 movies for year 1985.
# 2024-12-09 18:29:20,634 [INFO] Total movies collected so far: 9091
# 2024-12-09 18:29:24,624 [INFO] Fetched 122 movies for year 1984.
# 2024-12-09 18:29:24,628 [INFO] Total movies collected so far: 9213
# 2024-12-09 18:29:24,917 [INFO] Fetched 124 movies for year 1983.
# 2024-12-09 18:29:24,922 [INFO] Total movies collected so far: 9337
# 2024-12-09 18:29:25,132 [INFO] Fetched 119 movies for year 1982.
# 2024-12-09 18:29:25,135 [INFO] Total movies collected so far: 9456
# 2024-12-09 18:29:25,477 [INFO] Fetched 130 movies for year 1981.
# 2024-12-09 18:29:25,480 [INFO] Total movies collected so far: 9586
# 2024-12-09 18:29:25,655 [INFO] Fetched 115 movies for year 1980.
# 2024-12-09 18:29:25,658 [INFO] Total movies collected so far: 9701
# 2024-12-09 18:29:29,625 [INFO] Fetched 91 movies for year 1979.
# 2024-12-09 18:29:29,630 [INFO] Total movies collected so far: 9792
# 2024-12-09 18:29:30,080 [INFO] Fetched 86 movies for year 1978.
# 2024-12-09 18:29:30,083 [INFO] Total movies collected so far: 9878
# 2024-12-09 18:29:30,365 [INFO] Fetched 84 movies for year 1977.
# 2024-12-09 18:29:30,367 [INFO] Total movies collected so far: 9962
# 2024-12-09 18:29:30,572 [INFO] Fetched 89 movies for year 1976.
# 2024-12-09 18:29:30,575 [INFO] Total movies collected so far: 10051
# 2024-12-09 18:29:30,660 [INFO] Fetched 73 movies for year 1975.
# 2024-12-09 18:29:30,662 [INFO] Total movies collected so far: 10124
# 2024-12-09 18:29:34,867 [INFO] Fetched 87 movies for year 1974.
# 2024-12-09 18:29:34,873 [INFO] Total movies collected so far: 10211
# 2024-12-09 18:29:35,292 [INFO] Fetched 80 movies for year 1973.
# 2024-12-09 18:29:35,295 [INFO] Total movies collected so far: 10291
# 2024-12-09 18:29:35,477 [INFO] Fetched 96 movies for year 1972.
# 2024-12-09 18:29:35,483 [INFO] Total movies collected so far: 10387
# 2024-12-09 18:29:35,810 [INFO] Fetched 85 movies for year 1971.
# 2024-12-09 18:29:35,815 [INFO] Total movies collected so far: 10472
# 2024-12-09 18:29:35,931 [INFO] Fetched 84 movies for year 1970.
# 2024-12-09 18:29:35,933 [INFO] Total movies collected so far: 10556
# 2024-12-09 18:29:40,161 [INFO] Fetched 60 movies for year 1969.
# 2024-12-09 18:29:40,168 [INFO] Total movies collected so far: 10616
# 2024-12-09 18:29:40,551 [INFO] Fetched 66 movies for year 1968.
# 2024-12-09 18:29:40,554 [INFO] Total movies collected so far: 10682
# 2024-12-09 18:29:40,852 [INFO] Fetched 68 movies for year 1967.
# 2024-12-09 18:29:40,855 [INFO] Total movies collected so far: 10750
# 2024-12-09 18:29:41,232 [INFO] Fetched 70 movies for year 1965.
# 2024-12-09 18:29:41,232 [INFO] Fetched 71 movies for year 1966.
# 2024-12-09 18:29:41,235 [INFO] Total movies collected so far: 10820
# 2024-12-09 18:29:41,244 [INFO] Total movies collected so far: 10891
# 2024-12-09 18:29:45,393 [INFO] Fetched 74 movies for year 1964.
# 2024-12-09 18:29:45,396 [INFO] Total movies collected so far: 10965
# 2024-12-09 18:29:45,788 [INFO] Fetched 64 movies for year 1963.
# 2024-12-09 18:29:45,791 [INFO] Total movies collected so far: 11029
# 2024-12-09 18:29:46,135 [INFO] Fetched 57 movies for year 1962.
# 2024-12-09 18:29:46,139 [INFO] Total movies collected so far: 11086
# 2024-12-09 18:29:46,470 [INFO] Fetched 60 movies for year 1960.
# 2024-12-09 18:29:46,470 [INFO] Fetched 52 movies for year 1961.
# 2024-12-09 18:29:46,474 [INFO] Total movies collected so far: 11146
# 2024-12-09 18:29:46,482 [INFO] Total movies collected so far: 11198
# 2024-12-09 18:29:50,587 [INFO] Fetched 54 movies for year 1959.
# 2024-12-09 18:29:50,594 [INFO] Total movies collected so far: 11252
# 2024-12-09 18:29:50,995 [INFO] Fetched 47 movies for year 1958.
# 2024-12-09 18:29:51,000 [INFO] Total movies collected so far: 11299
# 2024-12-09 18:29:51,578 [INFO] Fetched 46 movies for year 1956.
# 2024-12-09 18:29:51,583 [INFO] Total movies collected so far: 11345
# 2024-12-09 18:29:51,623 [INFO] Fetched 43 movies for year 1957.
# 2024-12-09 18:29:51,626 [INFO] Total movies collected so far: 11388
# 2024-12-09 18:29:51,638 [INFO] Fetched 53 movies for year 1955.
# 2024-12-09 18:29:51,640 [INFO] Total movies collected so far: 11441
# 2024-12-09 18:29:55,007 [INFO] Fetched 40 movies for year 1954.
# 2024-12-09 18:29:55,014 [INFO] Total movies collected so far: 11481
# 2024-12-09 18:29:55,235 [INFO] Fetched 46 movies for year 1953.
# 2024-12-09 18:29:55,239 [INFO] Total movies collected so far: 11527
# 2024-12-09 18:29:55,642 [INFO] Fetched 36 movies for year 1952.
# 2024-12-09 18:29:55,648 [INFO] Total movies collected so far: 11563
# 2024-12-09 18:29:55,678 [INFO] Fetched 29 movies for year 1951.
# 2024-12-09 18:29:55,680 [INFO] Total movies collected so far: 11592
# 2024-12-09 18:29:55,868 [INFO] Fetched 29 movies for year 1950.
# 2024-12-09 18:29:55,876 [INFO] Total movies collected so far: 11621
# 2024-12-09 18:29:58,971 [INFO] Fetched 33 movies for year 1949.
# 2024-12-09 18:29:58,974 [INFO] Total movies collected so far: 11654
# 2024-12-09 18:29:59,858 [INFO] Fetched 31 movies for year 1948.
# 2024-12-09 18:29:59,866 [INFO] Total movies collected so far: 11685
# 2024-12-09 18:30:00,302 [INFO] Fetched 25 movies for year 1947.
# 2024-12-09 18:30:00,310 [INFO] Total movies collected so far: 11710
# 2024-12-09 18:30:00,674 [INFO] Fetched 27 movies for year 1946.
# 2024-12-09 18:30:00,681 [INFO] Total movies collected so far: 11737
# 2024-12-09 18:30:01,163 [INFO] Fetched 26 movies for year 1945.
# 2024-12-09 18:30:01,172 [INFO] Total movies collected so far: 11763
# 2024-12-09 18:30:03,230 [INFO] Fetched 20 movies for year 1944.
# 2024-12-09 18:30:03,245 [INFO] Total movies collected so far: 11783
# 2024-12-09 18:30:04,174 [INFO] Fetched 26 movies for year 1943.
# 2024-12-09 18:30:04,176 [INFO] Total movies collected so far: 11809
# 2024-12-09 18:30:04,604 [INFO] Fetched 23 movies for year 1942.
# 2024-12-09 18:30:04,615 [INFO] Total movies collected so far: 11832
# 2024-12-09 18:30:04,921 [INFO] Fetched 22 movies for year 1941.
# 2024-12-09 18:30:04,925 [INFO] Total movies collected so far: 11854
# 2024-12-09 18:30:05,380 [INFO] Fetched 22 movies for year 1940.
# 2024-12-09 18:30:05,385 [INFO] Total movies collected so far: 11876
# 2024-12-09 18:30:07,474 [INFO] Fetched 30 movies for year 1939.
# 2024-12-09 18:30:07,477 [INFO] Total movies collected so far: 11906
# 2024-12-09 18:30:08,014 [INFO] Fetched 19 movies for year 1938.
# 2024-12-09 18:30:08,020 [INFO] Total movies collected so far: 11925
# 2024-12-09 18:30:08,552 [INFO] Fetched 20 movies for year 1937.
# 2024-12-09 18:30:08,555 [INFO] Total movies collected so far: 11945
# 2024-12-09 18:30:08,931 [INFO] Fetched 17 movies for year 1936.
# 2024-12-09 18:30:08,937 [INFO] Total movies collected so far: 11962
# 2024-12-09 18:30:09,406 [INFO] Fetched 14 movies for year 1935.
# 2024-12-09 18:30:09,416 [INFO] Total movies collected so far: 11976
# 2024-12-09 18:30:09,417 [INFO] Total movies fetched: 11976
# 2024-12-09 18:30:09,419 [INFO] Starting to fetch credits for each movie...
# 2024-12-09 18:30:14,303 [INFO] Fetched credits for 100/11976 movies.
# 2024-12-09 18:30:18,452 [INFO] Fetched credits for 200/11976 movies.
# 2024-12-09 18:30:23,160 [INFO] Fetched credits for 300/11976 movies.
# 2024-12-09 18:30:27,999 [INFO] Fetched credits for 400/11976 movies.
# 2024-12-09 18:30:32,352 [INFO] Fetched credits for 500/11976 movies.
# 2024-12-09 18:30:37,040 [INFO] Fetched credits for 600/11976 movies.
# 2024-12-09 18:30:41,502 [INFO] Fetched credits for 700/11976 movies.
# 2024-12-09 18:30:46,133 [INFO] Fetched credits for 800/11976 movies.
# 2024-12-09 18:30:50,440 [INFO] Fetched credits for 900/11976 movies.
# 2024-12-09 18:30:55,007 [INFO] Fetched credits for 1000/11976 movies.
# 2024-12-09 18:30:59,696 [INFO] Fetched credits for 1100/11976 movies.
# 2024-12-09 18:31:03,596 [INFO] Fetched credits for 1200/11976 movies.
# 2024-12-09 18:31:07,968 [INFO] Fetched credits for 1300/11976 movies.
# 2024-12-09 18:31:12,266 [INFO] Fetched credits for 1400/11976 movies.
# 2024-12-09 18:31:16,823 [INFO] Fetched credits for 1500/11976 movies.
# 2024-12-09 18:31:21,732 [INFO] Fetched credits for 1600/11976 movies.
# 2024-12-09 18:31:26,420 [INFO] Fetched credits for 1700/11976 movies.
# 2024-12-09 18:31:31,187 [INFO] Fetched credits for 1800/11976 movies.
# 2024-12-09 18:31:36,064 [INFO] Fetched credits for 1900/11976 movies.
# 2024-12-09 18:31:41,849 [INFO] Fetched credits for 2000/11976 movies.
# 2024-12-09 18:31:47,453 [INFO] Fetched credits for 2100/11976 movies.
# 2024-12-09 18:31:52,447 [INFO] Fetched credits for 2200/11976 movies.
# 2024-12-09 18:31:57,014 [INFO] Fetched credits for 2300/11976 movies.
# 2024-12-09 18:32:01,718 [INFO] Fetched credits for 2400/11976 movies.
# 2024-12-09 18:32:06,166 [INFO] Fetched credits for 2500/11976 movies.
# 2024-12-09 18:32:10,472 [INFO] Fetched credits for 2600/11976 movies.
# 2024-12-09 18:32:15,103 [INFO] Fetched credits for 2700/11976 movies.
# 2024-12-09 18:32:19,771 [INFO] Fetched credits for 2800/11976 movies.
# 2024-12-09 18:32:24,180 [INFO] Fetched credits for 2900/11976 movies.
# 2024-12-09 18:32:28,515 [INFO] Fetched credits for 3000/11976 movies.
# 2024-12-09 18:32:32,827 [INFO] Fetched credits for 3100/11976 movies.
# 2024-12-09 18:32:37,302 [INFO] Fetched credits for 3200/11976 movies.
# 2024-12-09 18:32:40,906 [INFO] Fetched credits for 3300/11976 movies.
# 2024-12-09 18:32:44,597 [INFO] Fetched credits for 3400/11976 movies.
# 2024-12-09 18:32:48,397 [INFO] Fetched credits for 3500/11976 movies.
# 2024-12-09 18:32:52,268 [INFO] Fetched credits for 3600/11976 movies.
# 2024-12-09 18:32:57,685 [INFO] Fetched credits for 3700/11976 movies.
# 2024-12-09 18:33:02,317 [INFO] Fetched credits for 3800/11976 movies.
# 2024-12-09 18:33:07,056 [INFO] Fetched credits for 3900/11976 movies.
# 2024-12-09 18:33:11,453 [INFO] Fetched credits for 4000/11976 movies.
# 2024-12-09 18:33:15,834 [INFO] Fetched credits for 4100/11976 movies.
# 2024-12-09 18:33:20,896 [INFO] Fetched credits for 4200/11976 movies.
# 2024-12-09 18:33:25,798 [INFO] Fetched credits for 4300/11976 movies.
# 2024-12-09 18:33:30,618 [INFO] Fetched credits for 4400/11976 movies.
# 2024-12-09 18:33:35,270 [INFO] Fetched credits for 4500/11976 movies.
# 2024-12-09 18:33:39,120 [INFO] Fetched credits for 4600/11976 movies.
# 2024-12-09 18:33:42,745 [INFO] Fetched credits for 4700/11976 movies.
# 2024-12-09 18:33:46,850 [INFO] Fetched credits for 4800/11976 movies.
# 2024-12-09 18:33:50,369 [INFO] Fetched credits for 4900/11976 movies.
# 2024-12-09 18:33:54,640 [INFO] Fetched credits for 5000/11976 movies.
# 2024-12-09 18:33:59,695 [INFO] Fetched credits for 5100/11976 movies.
# 2024-12-09 18:34:04,929 [INFO] Fetched credits for 5200/11976 movies.
# 2024-12-09 18:34:09,979 [INFO] Fetched credits for 5300/11976 movies.
# 2024-12-09 18:34:14,221 [INFO] Fetched credits for 5400/11976 movies.
# 2024-12-09 18:34:18,216 [INFO] Fetched credits for 5500/11976 movies.
# 2024-12-09 18:34:22,474 [INFO] Fetched credits for 5600/11976 movies.
# 2024-12-09 18:34:26,431 [INFO] Fetched credits for 5700/11976 movies.
# 2024-12-09 18:34:30,089 [INFO] Fetched credits for 5800/11976 movies.
# 2024-12-09 18:34:34,413 [INFO] Fetched credits for 5900/11976 movies.
# 2024-12-09 18:34:38,474 [INFO] Fetched credits for 6000/11976 movies.
# 2024-12-09 18:34:42,543 [INFO] Fetched credits for 6100/11976 movies.
# 2024-12-09 18:34:46,585 [INFO] Fetched credits for 6200/11976 movies.
# 2024-12-09 18:34:50,396 [INFO] Fetched credits for 6300/11976 movies.
# 2024-12-09 18:34:54,202 [INFO] Fetched credits for 6400/11976 movies.
# 2024-12-09 18:34:57,871 [INFO] Fetched credits for 6500/11976 movies.
# 2024-12-09 18:35:01,698 [INFO] Fetched credits for 6600/11976 movies.
# 2024-12-09 18:35:06,062 [INFO] Fetched credits for 6700/11976 movies.
# 2024-12-09 18:35:10,132 [INFO] Fetched credits for 6800/11976 movies.
# 2024-12-09 18:35:14,476 [INFO] Fetched credits for 6900/11976 movies.
# 2024-12-09 18:35:18,307 [INFO] Fetched credits for 7000/11976 movies.
# 2024-12-09 18:35:22,673 [INFO] Fetched credits for 7100/11976 movies.
# 2024-12-09 18:35:27,111 [INFO] Fetched credits for 7200/11976 movies.
# 2024-12-09 18:35:31,715 [INFO] Fetched credits for 7300/11976 movies.
# 2024-12-09 18:35:35,640 [INFO] Fetched credits for 7400/11976 movies.
# 2024-12-09 18:35:39,359 [INFO] Fetched credits for 7500/11976 movies.
# 2024-12-09 18:35:43,287 [INFO] Fetched credits for 7600/11976 movies.
# 2024-12-09 18:35:47,330 [INFO] Fetched credits for 7700/11976 movies.
# 2024-12-09 18:35:51,615 [INFO] Fetched credits for 7800/11976 movies.
# 2024-12-09 18:35:56,039 [INFO] Fetched credits for 7900/11976 movies.
# 2024-12-09 18:36:00,176 [INFO] Fetched credits for 8000/11976 movies.
# 2024-12-09 18:36:04,506 [INFO] Fetched credits for 8100/11976 movies.
# 2024-12-09 18:36:08,636 [INFO] Fetched credits for 8200/11976 movies.
# 2024-12-09 18:36:12,873 [INFO] Fetched credits for 8300/11976 movies.
# 2024-12-09 18:36:17,145 [INFO] Fetched credits for 8400/11976 movies.
# 2024-12-09 18:36:21,188 [INFO] Fetched credits for 8500/11976 movies.
# 2024-12-09 18:36:25,805 [INFO] Fetched credits for 8600/11976 movies.
# 2024-12-09 18:36:30,875 [INFO] Fetched credits for 8700/11976 movies.
# 2024-12-09 18:36:35,948 [INFO] Fetched credits for 8800/11976 movies.
# 2024-12-09 18:36:40,782 [INFO] Fetched credits for 8900/11976 movies.
# 2024-12-09 18:36:44,788 [INFO] Fetched credits for 9000/11976 movies.
# 2024-12-09 18:36:48,766 [INFO] Fetched credits for 9100/11976 movies.
# 2024-12-09 18:36:52,721 [INFO] Fetched credits for 9200/11976 movies.
# 2024-12-09 18:36:56,546 [INFO] Fetched credits for 9300/11976 movies.
# 2024-12-09 18:37:00,306 [INFO] Fetched credits for 9400/11976 movies.
# 2024-12-09 18:37:04,422 [INFO] Fetched credits for 9500/11976 movies.
# 2024-12-09 18:37:08,172 [INFO] Fetched credits for 9600/11976 movies.
# 2024-12-09 18:37:11,922 [INFO] Fetched credits for 9700/11976 movies.
# 2024-12-09 18:37:15,699 [INFO] Fetched credits for 9800/11976 movies.
# 2024-12-09 18:37:19,311 [INFO] Fetched credits for 9900/11976 movies.
# 2024-12-09 18:37:23,352 [INFO] Fetched credits for 10000/11976 movies.
# 2024-12-09 18:37:27,416 [INFO] Fetched credits for 10100/11976 movies.
# 2024-12-09 18:37:31,281 [INFO] Fetched credits for 10200/11976 movies.
# 2024-12-09 18:37:35,559 [INFO] Fetched credits for 10300/11976 movies.
# 2024-12-09 18:37:39,561 [INFO] Fetched credits for 10400/11976 movies.
# 2024-12-09 18:37:43,891 [INFO] Fetched credits for 10500/11976 movies.
# 2024-12-09 18:37:48,382 [INFO] Fetched credits for 10600/11976 movies.
# 2024-12-09 18:37:52,912 [INFO] Fetched credits for 10700/11976 movies.
# 2024-12-09 18:37:57,278 [INFO] Fetched credits for 10800/11976 movies.
# 2024-12-09 18:38:01,802 [INFO] Fetched credits for 10900/11976 movies.
# 2024-12-09 18:38:06,291 [INFO] Fetched credits for 11000/11976 movies.
# 2024-12-09 18:38:10,251 [INFO] Fetched credits for 11100/11976 movies.
# 2024-12-09 18:38:14,345 [INFO] Fetched credits for 11200/11976 movies.
# 2024-12-09 18:38:18,371 [INFO] Fetched credits for 11300/11976 movies.
# 2024-12-09 18:38:22,613 [INFO] Fetched credits for 11400/11976 movies.
# 2024-12-09 18:38:26,825 [INFO] Fetched credits for 11500/11976 movies.
# 2024-12-09 18:38:31,818 [INFO] Fetched credits for 11600/11976 movies.
# 2024-12-09 18:38:36,536 [INFO] Fetched credits for 11700/11976 movies.
# 2024-12-09 18:38:41,785 [INFO] Fetched credits for 11800/11976 movies.
# 2024-12-09 18:38:47,038 [INFO] Fetched credits for 11900/11976 movies.
# 2024-12-09 18:38:50,887 [INFO] Fetched credits for 11976/11976 movies.
# 2024-12-09 18:38:50,894 [INFO] Completed fetching credits for all movies in 521.47 seconds.
# 2024-12-09 18:38:52,911 [INFO] Saved 11976 movies to 'top20k_movies_project2.csv'.
# 2024-12-09 18:38:52,912 [INFO] Execution time: 619.71 seconds.
